# %%
# Colab use sample code
import os
if not os.path.exists('/content/your-ml-project'):
    # !git clone https://github.com/user/your-ml-project.git
    # %cd your-ml-project
    # !pip install -r requirements.txt
from google.colab import drive
drive.mount('/content/drive')
